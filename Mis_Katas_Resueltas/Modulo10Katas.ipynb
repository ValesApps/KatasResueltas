# %%
open("/path/to/mars.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\RaulCurly\Desktop\LAUNCHX\Mis_Katas_Resueltas\Modulo10Katas.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/RaulCurly/Desktop/LAUNCHX/Mis_Katas_Resueltas/Modulo10Katas.ipynb#ch0000001?line=0'>1</a> open("/path/to/mars.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/path/to/mars.jpg'

# %%
from IPython.display import Image
Image(filename="kata10_001.png")

# %%
from IPython.display import Image
Image(filename="kata10_002.png")
